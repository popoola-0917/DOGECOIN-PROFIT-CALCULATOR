-06-26,0.002417,0.002427,0.002359,0.002359,0.002359,151319087\n2020-06-27,0.002359,0.002379,0.002294,0.002313,0.002313,152534000\n2020-06-28,0.002313,0.002361,0.002283,0.002326,0.002326,172693834\n2020-06-29,0.002326,0.002341,0.002301,0.002313,0.002313,172655788\n2020-06-30,0.002311,0.002340,0.002297,0.002320,0.002320,165641131\n2020-07-01,0.002320,0.002376,0.002301,0.002354,0.002354,152549214\n2020-07-02,0.002330,0.002382,0.002302,0.002361,0.002361,110789127\n2020-07-03,0.002361,0.002366,0.002304,0.002316,0.002316,111575143\n2020-07-04,0.002315,0.002340,0.002289,0.002309,0.002309,109218071\n2020-07-05,0.002307,0.002327,0.002277,0.002309,0.002309,110140542\n2020-07-06,0.002309,0.002624,0.002302,0.002616,0.002616,132105139\n2020-07-07,0.002614,0.003259,0.002600,0.003090,0.003090,283970310\n2020-07-08,0.003097,0.005420,0.003061,0.004750,0.004750,1226813925\n2020-07-09,0.004732,0.005014,0.004148,0.004397,0.00 ...

# %%
#Get the stock data
df = pd.read_csv('DOGECOIN.csv')
#set the date as index
df = df.set_index(pd.DatetimeIndex(df['Date'].values))
#show the data
df
# Out:
#                   Date      Open      High  ...     Close  Adj Close        Volume
# 2020-05-12  2020-05-12  0.002413  0.002513  ...  0.002463   0.002463  2.629345e+08
# 2020-05-13  2020-05-13  0.002464  0.002528  ...  0.002521   0.002521  2.658781e+08
# 2020-05-14  2020-05-14  0.002518  0.002623  ...  0.002574   0.002574  2.837786e+08
# 2020-05-15  2020-05-15  0.002574  0.002577  ...  0.002506   0.002506  2.610802e+08
# 2020-05-16  2020-05-16  0.002507  0.002534  ...  0.002513   0.002513  2.546665e+08
# ...                ...       ...       ...  ...       ...        ...           ...
# 2021-05-08  2021-05-08  0.687801  0.737567  ...  0.636439   0.636439  2.555513e+10
# 2021-05-09  2021-05-09  0.635820  0.697625  ...  0.570070   0.570070  4.613806e+10
# 2021-05-10  2021-05-10  0.569687  0.569687  ...  0.449964   0.449964  1.651452e+10
# 2021-05-11  2021-05-11  0.450488  0.546651  ...  0.495231   0.495231  1.456698e+10
# 2021-05-12  2021-05-12  0.491521  0.516528  ...  0.500823   0.500823  9.692967e+09
#
# [366 rows x 7 columns]

# %%
#Ask the user the amount of money that they invested and the date it was been invested
amount_invested = input('Enter Amount invested in Dollars: ')
print(amount_invested)
invest_date = input('Enter the Date that you invested: ')
print(invest_date)
# Out:
# Enter Amount invested in Dollars: 35
# 35
# Enter the Date that you invested: 2021-05-11
# 2021-05-11

# %%
#Get the low and the high price for the day that the user invested to get a price range


#Create variable to store the low and high price column names
col1 = 'Low'
col2 = 'High'

#Get the low and high price of the asset for the specific day that the user invested
price1 = df[col1][invest_date]
price2 = df[col2][invest_date]
#Compute the quantity of asset the user would have
quantity1 = int(amount_invested) /price1
quantity2 = int(amount_invested) / price2
#Compute the profit range
profit1 = (quantity1 * df[col1][-1] - int(amount_invested))
profit2 = (quantity2 * df[col1][-1] - int(amount_invested))

#Print the range the amount would have made or lost
print('You would have made between $', round(profit1, 2), 'and $', round(profit2, 2), 'as of', df['Date'][-1] )
# Out:
# You would have made between $ 2.99 and $ -4.07 as of 2021-05-12

# %%
#Compute the Return on Investment (ROI) range
ROI1 = profit1 / int(amount_invested) *100
ROI2 = profit2 / int(amount_invested) *100

#Print the ROI range
print('Your return on investment(ROI) would  be between', round(ROI1, 2), '%and', round(ROI2, 2),  '% as of', df['Date'][-1])
# Out:
# Your return on investment(ROI) would  be between 8.55 %and -11.63 % as of 2021-05-12
